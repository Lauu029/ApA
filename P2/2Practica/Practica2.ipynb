# %%
from utils import load_data_multi
from multi_linear_reg import compute_cost
from multi_linear_reg import zscore_normalize_features
from multi_linear_reg import compute_gradient
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
import numpy as np

X,Y  = load_data_multi()

# %%
# Crear una figura 3D
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# Extraer los valores X
X1 = X[:, 0]
X2 = X[:, 1]
X3 = X[:,2]
# Crear el gráfico 3D
ax.scatter(X1, X2, Y, c='b', marker='o')

# Etiquetas de los ejes
ax.set_xlabel('Numero habitaciones')
ax.set_ylabel('Numero de plantas')
ax.set_zlabel('Precio')

# Mostrar el gráfico 3D
plt.title('Gráfico 3D de Precios vs. atributos de la casa')
plt.show()

plt.scatter(X1, Y, color="blue", s=3)
plt.title("Puntos del dataset")
plt.xlabel("X")
plt.ylabel("Y")
plt.grid(True)
plt.show()

# %%
X_Norm1, mu1, sigma1 = zscore_normalize_features(X1)
X_Norm2, mu2, sigma2 = zscore_normalize_features(X2)
X_Norm3, mu3, sigma3 = zscore_normalize_features(X3)

# %%
from public_tests import compute_cost_test
compute_cost_test(compute_cost)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[24], line 2
#       1 from public_tests import compute_cost_test
# ----> 2 compute_cost_test(compute_cost)
#
# File ~\Documents\Desarrollo_de_Videojuegos\4\1Cuatri\Apa\Practicas\ApA\P2\2Practica\public_tests.py:19, in compute_cost_test(target)
#      17 cost = target(X_train, y_train, w_init, b_init)
#      18 target_cost = 1.5578904045996674e-12
# ---> 19 assert np.isclose(
#      20     cost, target_cost, rtol=1e-4), f"Case 1: Cost must be {target_cost} for a perfect prediction but got {cost}"
#      22 print("\033All tests passed!")
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()

# %%
from public_tests import compute_gradient_test
compute_gradient_test(compute_gradient)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[25], line 2
#       1 from public_tests import compute_gradient_test
# ----> 2 compute_gradient_test(compute_gradient)
#
# File ~\Documents\Desarrollo_de_Videojuegos\4\1Cuatri\Apa\Practicas\ApA\P2\2Practica\public_tests.py:28, in compute_gradient_test(target)
#      25 def compute_gradient_test(target):
#      26     X_train, y_train, w_init, b_init = test_data()
# ---> 28     dj_db, dj_dw = target(X_train, y_train, w_init, b_init)
#      29     #assert dj_dw.shape == w_init.shape, f"Wrong shape for dj_dw. {dj_dw} != {w_init.shape}"
#      31     target_dj_db = -1.6739251122999121e-06
#
# File ~\Documents\Desarrollo_de_Videojuegos\4\1Cuatri\Apa\Practicas\ApA\P2\2Practica\multi_linear_reg.py:57, in compute_gradient(X, y, w, b)
#      45 """
#      46 Computes the gradient for linear regression
#      47 Args:
#    (...)
# ...

# %%
from public_tests import compute_gradient_test
