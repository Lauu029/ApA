# %%
from utils import load_data_multi
from multi_linear_reg import compute_cost
from multi_linear_reg import zscore_normalize_features
from multi_linear_reg import compute_gradient
from multi_linear_reg import gradient_descent
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
import numpy as np

# %%
X,Y  = load_data_multi()
Y=Y.flatten()
# Crear una figura 3D
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# Extraer los valores X
X1 = X[:, 0]
X2 = X[:, 1]
X3 = X[:,2]
x4 = X[:, 3]
# Crear el gráfico 3D
ax.scatter(X1, X2, Y, c='b', marker='o',s=3)

# Etiquetas de los ejes
ax.set_xlabel('Numero habitaciones')
ax.set_ylabel('Numero de plantas')
ax.set_zlabel('Precio')

# Mostrar el gráfico 3D
plt.title('Precios -> atributos de la casa')
plt.show()

plt.scatter(X1, Y, color="blue", s=2)
plt.title("Puntos del dataset")
plt.xlabel("X")
plt.ylabel("Y")
plt.grid(True)
plt.show()

# %%
from public_tests import compute_cost_test
compute_cost_test(compute_cost)
# Out:
# All tests passed!

# %%
from public_tests import compute_gradient_test
compute_gradient_test(compute_gradient)
# Out:
# All tests passed!

# %%
from public_tests import sklearn_linearmodel
X_Norm, mu, sigma =  zscore_normalize_features(X);

w_in=[0,0,0,0]
b_in=0
alpha=0.01
num_iters=1600

w, b, J_History=gradient_descent(X_Norm,Y, w_in, b_in, compute_cost, compute_gradient, alpha, num_iters)
print(f"Regresion multivariable: {w} {b}")
sklearn_linearmodel(X_Norm,Y)
# Out:
# Regresion multivariable: [110.2026322  -21.26652798 -32.43210575 -37.85933282] 362.2394823896666
# sklearn:  [110.61335173 -21.47323884 -32.66070323 -37.77938362] 362.23952
# (array([110.61335173, -21.47323884, -32.66070323, -37.77938362]), 362.23952)
