# %% [markdown]
# # Preprocessing data with pandas

# %% [markdown]
# **Nombres de los alumnos**
#
# Laura Gómez Bodego
#
# Sergio Baña Marchante

# %% [markdown]
# ## Pandas
#
# Python Data Analysis Library) an open source (BSD) library designed to process data with high performance.
# Some definitions:
#
# - **Dataframe**: the main structure of Pandas. Is similat to a database table or a excell leaf.
# - **CSV**: Is the most commonly used dataset format in machine learning. It is a text file with training each one stored on one line

# %% [markdown]
# Load datase

# %%
import pandas as pd
import numpy as np
gameSales = pd.read_csv('dato.csv')

# %%
display(gameSales)
display(gameSales.head(n=4));
display(gameSales.tail(n=4));
# Out:
#      Platform     Genre             Publisher NA_Sales EU_Sales JP_Sales  \
# 0         Wii    Sports              Nintendo    41,36    28,96     3,77
# 1         Wii    Racing              Nintendo    15,68     12,8     3,79
# 2         Wii    Sports              Nintendo    15,61    10,95     3,28
# 3          DS  Platform              Nintendo    11,28     9,15      6,5
# 4         Wii      Misc              Nintendo    13,96     9,18     2,93
# ...       ...       ...                   ...      ...      ...      ...
# 7107       PC    Action               Ubisoft        0        0        0
# 7108       PC   Shooter          Midway Games        0        0        0
# 7109       PC    Sports                  Sega        0        0        0
# 7110       PC  Strategy  Take-Two Interactive        0        0        0
# 7111      PS4  Platform             Team Meat        0        0        0
#
#      Other_Sales Global_Sales Rating Critic_Score_Class
# ...

# %% [markdown]
# Find NaN values

# %%
gameSales.isna()
# Out:
#       Platform  Genre  Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# 0        False  False      False     False     False     False        False
# 1        False  False      False     False     False     False        False
# 2        False  False      False     False     False     False        False
# 3        False  False      False     False     False     False        False
# 4        False  False      False     False     False     False        False
# ...        ...    ...        ...       ...       ...       ...          ...
# 7107     False  False      False     False     False     False        False
# 7108     False  False      False     False     False     False        False
# 7109     False  False      False     False     False     False        False
# 7110     False  False      False     False     False     False        False
# 7111     False  False      False     False     False     False        False
#
#       Global_Sales  Rating  Critic_Score_Class
# ...

# %% [markdown]
# any(axis) function check if any value in each row (index) is True. axis	0 1 ('index''columns')

# %%
gameSales[gameSales.isna().any(axis=1)]
#Dataframe.(nombredecolumna).mean()->  media 
#Dataframe(nombre de la columna).fillna(media calculada,implace=true)
#para todas a la vez me creo un vector de medias nombredataframe.mean
# Out:
#      Platform       Genre    Publisher NA_Sales EU_Sales JP_Sales Other_Sales  \
# 0         Wii      Sports     Nintendo    41,36    28,96     3,77        8,45
# 15         DS      Puzzle     Nintendo     3,43     5,35     5,32        1,18
# 4868       PC     Shooter         Sega        0     0,14        0        0,01
# 5042        X  Simulation  Codemasters      0,1      NaN        0           0
# 5101       GC        Misc       Capcom      0,1     0,03        0           0
#
#      Global_Sales Rating Critic_Score_Class
# 0           82,54    NaN              Bueno
# 15          15,29    NaN              Bueno
# 4868          NaN      M          Excelente
# 5042         0,13      T              Bueno
# 5101         0,13    NaN              Bueno

# %% [markdown]
# we can looking for a specific column by filtering by column.

# %%
gameSales[gameSales["Global_Sales"].isna()]
# Out:
#      Platform    Genre Publisher NA_Sales EU_Sales JP_Sales Other_Sales  \
# 4868       PC  Shooter      Sega        0     0,14        0        0,01
#
#      Global_Sales Rating Critic_Score_Class
# 4868          NaN      M          Excelente

# %% [markdown]
# there are other useful methods for finding errors such as:
# - notna()
# - isnull()
# - notnull()
#
# We can search for a specific value

# %%
gameSales[gameSales["Publisher"] == "Capcom"]
# Out:
#      Platform         Genre Publisher NA_Sales EU_Sales JP_Sales Other_Sales  \
# 120       PSP  Role-Playing    Capcom     0,47     0,55     4,13        0,34
# 141       PS3        Action    Capcom     1,96     1,41     1,08        0,64
# 196       PS3      Fighting    Capcom     2,03     1,04     0,58        0,52
# 240       PS2        Action    Capcom     2,08     0,83     0,46        0,25
# 256      X360        Action    Capcom     2,11     0,93     0,12        0,34
# ...       ...           ...       ...      ...      ...      ...         ...
# 6860        X        Action    Capcom     0,01        0        0           0
# 6876       PC        Action    Capcom        0     0,01        0           0
# 6902       PC        Action    Capcom        0     0,01        0           0
# 7038     X360      Fighting    Capcom        0        0     0,01           0
# 7065       PC        Racing    Capcom        0     0,01        0           0
#
#      Global_Sales Rating Critic_Score_Class
# ...

# %% [markdown]
# ApplyMap allows us to make a more detailed query (Mask).

# %%
mask = gameSales.applymap(lambda x:  "capco".lower() in str(x).lower())
display(gameSales[mask.any(axis=1)])
# Out:
#      Platform         Genre Publisher NA_Sales EU_Sales JP_Sales Other_Sales  \
# 120       PSP  Role-Playing    Capcom     0,47     0,55     4,13        0,34
# 141       PS3        Action    Capcom     1,96     1,41     1,08        0,64
# 196       PS3      Fighting    Capcom     2,03     1,04     0,58        0,52
# 240       PS2        Action    Capcom     2,08     0,83     0,46        0,25
# 256      X360        Action    Capcom     2,11     0,93     0,12        0,34
# ...       ...           ...       ...      ...      ...      ...         ...
# 6860        X        Action    Capcom     0,01        0        0           0
# 6876       PC        Action    Capcom        0     0,01        0           0
# 6902       PC        Action    Capcom        0     0,01        0           0
# 7038     X360      Fighting    Capcom        0        0     0,01           0
# 7065       PC        Racing    Capcom        0     0,01        0           0
#
#      Global_Sales Rating Critic_Score_Class
# ...

# %% [markdown]
# Now we are looking for the best-selling video game in Japan.
# For this we look at the column types

# %%
display(gameSales.dtypes)
# Out:
# Platform              object
# Genre                 object
# Publisher             object
# NA_Sales              object
# EU_Sales              object
# JP_Sales              object
# Other_Sales           object
# Global_Sales          object
# Rating                object
# Critic_Score_Class    object
# dtype: object

# %% [markdown]
# And change the type in numeric colums

# %%
gameSales["JP_Sales"] = gameSales["JP_Sales"].astype(np.float32)
display(gameSales.dtypes)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 gameSales["JP_Sales"] = gameSales["JP_Sales"].astype(np.float32)
#       2 display(gameSales.dtypes)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:6240, in NDFrame.astype(self, dtype, copy, errors)
#    6233     results = [
#    6234         self.iloc[:, i].astype(dtype, copy=copy)
#    6235         for i in range(len(self.columns))
#    6236     ]
#    6238 else:
#    6239     # else, only a single dtype is given
# -> 6240     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6241     return self._constructor(new_data).__finalize__(self, method="astype")
#    6243 # GH 33113: handle empty frame or series
#
# File ~\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:448, in BaseBlockManager.astype(self, dtype, copy, errors)
# ...

# %% [markdown]
# but it gives us an error because 3.77 is not convertible to float, we have to change the character to a dot.

# %%
gameSales["JP_Sales"] = gameSales["JP_Sales"].apply(lambda x:  str(x).replace(",","."))

# %%
gameSales["JP_Sales"] = gameSales["JP_Sales"].astype(np.float32)
display(gameSales.dtypes)
# Out:
# Platform               object
# Genre                  object
# Publisher              object
# NA_Sales               object
# EU_Sales               object
# JP_Sales              float32
# Other_Sales            object
# Global_Sales           object
# Rating                 object
# Critic_Score_Class     object
# dtype: object

# %% [markdown]
# Repeat the process for all numeric columns.

# %%
gameSales["NA_Sales"] = gameSales["NA_Sales"].apply(lambda x:  str(x).replace(",","."))
gameSales["NA_Sales"] = gameSales["NA_Sales"].astype(np.float32)
gameSales["EU_Sales"] = gameSales["EU_Sales"].apply(lambda x:  str(x).replace(",","."))
gameSales["EU_Sales"] = gameSales["EU_Sales"].astype(np.float32)
gameSales["Other_Sales"] = gameSales["Other_Sales"].apply(lambda x:  str(x).replace(",","."))
gameSales["Other_Sales"] = gameSales["Other_Sales"].astype(np.float32)
gameSales["Global_Sales"] = gameSales["Global_Sales"].apply(lambda x:  str(x).replace(",","."))
gameSales["Global_Sales"] = gameSales["Global_Sales"].astype(np.float32)
display(gameSales.dtypes)
# Out:
# Platform               object
# Genre                  object
# Publisher              object
# NA_Sales              float32
# EU_Sales              float32
# JP_Sales              float32
# Other_Sales           float32
# Global_Sales          float32
# Rating                 object
# Critic_Score_Class     object
# dtype: object

# %%
gameSales[gameSales["JP_Sales"] == gameSales["JP_Sales"].max()]
# Out:
#   Platform     Genre Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# 3       DS  Platform  Nintendo     11.28      9.15       6.5         2.88
#
#    Global_Sales Rating Critic_Score_Class
# 3     29.809999      E          Excelente

# %% [markdown]
# Best sale by console.
# For this we look at the column types

# %%
groupByPlatfoms = gameSales.groupby("Platform")
mostPlatformGame = groupByPlatfoms.max(numeric_only=True)
display(mostPlatformGame)
# Out:
#            NA_Sales   EU_Sales  JP_Sales  Other_Sales  Global_Sales
# Platform
# 3DS        5.200000   4.190000      4.43         0.94     13.040000
# DC         1.020000   0.240000      0.52         0.04      1.180000
# DS        11.280000   9.200000      6.50         2.88     29.809999
# GBA        3.140000   1.640000      2.06         0.23      6.410000
# GC         4.410000   1.260000      1.39         0.22      7.070000
# PC         4.030000   6.420000      0.09         1.18      8.010000
# PS         4.020000   3.870000      3.63         0.96     10.950000
# PS2        9.430000   5.490000      3.61        10.57     20.809999
# PS3        7.020000   9.140000      1.87         3.97     21.120001
# PS4        4.120000   6.770000      0.81         2.08     13.360000
# PSP        2.900000   2.810000      4.13         1.73      7.690000
# PSV        0.720000   0.660000      0.38         0.28      1.540000
# Wii       41.360001  28.959999      4.70         8.45     82.540001
# ...

# %% [markdown]
# now we are left with only the overall sales column

# %%
mostPlatformGame = mostPlatformGame.drop('NA_Sales', axis=1)
mostPlatformGame = mostPlatformGame.drop('EU_Sales', axis=1)
mostPlatformGame = mostPlatformGame.drop('JP_Sales', axis=1)
mostPlatformGame = mostPlatformGame.drop('Other_Sales', axis=1)

# %%
display(mostPlatformGame)
# Out:
#           Global_Sales
# Platform
# 3DS          13.040000
# DC            1.180000
# DS           29.809999
# GBA           6.410000
# GC            7.070000
# PC            8.010000
# PS           10.950000
# PS2          20.809999
# PS3          21.120001
# PS4          13.360000
# PSP           7.690000
# PSV           1.540000
# Wii          82.540001
# WiiU          7.230000
# X             8.490000
# X360         21.860001
# XOne          5.740000

# %%
If we want to know which is the best-selling game of all the consoles, we remove the PC.
# Out:
#   Cell In[50], line 1
#     If we want to know which is the best-selling game of all the consoles, we remove the PC.
#        ^
# SyntaxError: invalid syntax

# %%
mostPlatformGame=mostPlatformGame.reset_index()
mostPlatformGame = mostPlatformGame.drop(mostPlatformGame[mostPlatformGame.Platform == "PC"].index)
display(mostPlatformGame)
# Out:
#    Platform  Global_Sales
# 0       3DS     13.040000
# 1        DC      1.180000
# 2        DS     29.809999
# 3       GBA      6.410000
# 4        GC      7.070000
# 6        PS     10.950000
# 7       PS2     20.809999
# 8       PS3     21.120001
# 9       PS4     13.360000
# 10      PSP      7.690000
# 11      PSV      1.540000
# 12      Wii     82.540001
# 13     WiiU      7.230000
# 14        X      8.490000
# 15     X360     21.860001
# 16     XOne      5.740000

# %%
mostPlatformGame[mostPlatformGame["Global_Sales"] == mostPlatformGame["Global_Sales"].max()]
# Out:
#    Platform  Global_Sales
# 12      Wii     82.540001

# %% [markdown]
# Now let's see which first party game is the best seller on each platform.

# %%
firstParty = pd.read_csv('first_party.csv')
display(firstParty)
# Out:
#    Platform First_Party
# 0       Wii    Nintendo
# 1        DS    Nintendo
# 2       3DS    Nintendo
# 3        GC    Nintendo
# 4      WIIU    Nintendo
# 5       GBA    Nintendo
# 6      VBoy    Nintendo
# 7        PS        Sony
# 8       PS2        Sony
# 9       PS3        Sony
# 10      PS4        Sony
# 11      PS5        Sony
# 12      PSP        Sony
# 13      PSV        Sony
# 14        x   Microsoft
# 15     X360   Microsoft
# 16     XONE   Microsoft
# 17       DC        Sega

# %% [markdown]
# We have to make a merge of both tables in order to know which platforms belong to which brand of consoles.

# %%
gameSalesMerge = pd.merge(gameSales,firstParty,how='outer',on=('Platform'), indicator=True)
display(gameSalesMerge)
# Out:
#      Platform     Genre Publisher   NA_Sales   EU_Sales  JP_Sales  \
# 0         Wii    Sports  Nintendo  41.360001  28.959999      3.77
# 1         Wii    Racing  Nintendo  15.680000  12.800000      3.79
# 2         Wii    Sports  Nintendo  15.610000  10.950000      3.28
# 3         Wii      Misc  Nintendo  13.960000   9.180000      2.93
# 4         Wii  Platform  Nintendo  14.480000   6.950000      4.70
# ...       ...       ...       ...        ...        ...       ...
# 7112     WIIU       NaN       NaN        NaN        NaN       NaN
# 7113     VBoy       NaN       NaN        NaN        NaN       NaN
# 7114      PS5       NaN       NaN        NaN        NaN       NaN
# 7115        x       NaN       NaN        NaN        NaN       NaN
# 7116     XONE       NaN       NaN        NaN        NaN       NaN
#
#       Other_Sales  Global_Sales Rating Critic_Score_Class First_Party  \
# 0            8.45     82.540001    NaN              Bueno    Nintendo
# ...

# %% [markdown]
# Now we group by first_Party and keep the one with the largest sales.

# %%
gameSalesMergeGB = gameSalesMerge.groupby("First_Party")
gameSalesMergeFilter = gameSalesMergeGB.max(numeric_only=True)
display(gameSalesMergeFilter)
# Out:
#               NA_Sales   EU_Sales  JP_Sales  Other_Sales  Global_Sales
# First_Party
# Microsoft    15.020000   5.170000      0.24         1.69     21.860001
# Nintendo     41.360001  28.959999      6.50         8.45     82.540001
# Sega          1.020000   0.240000      0.52         0.04      1.180000
# Sony          9.430000   9.140000      4.13        10.57     21.120001

# %% [markdown]
# # Exercises

# %% [markdown]
# ## Pandas 0.5p
#
# 1. Get the platform that has no First_Party and the First_Party console that has no sales.
# 2. Cleans the dataset of numerical errors (NaN) by imputing the average value of each column to the missing data.
# 3. In the work folder there is a csv about video game developers (video-games-developers.csv). Clean the dataframe from missing or erroneous values and work with it the way you want.
#
# **Answer in this Notebook**
#
# ## Python 0.5p
#
# 1. Solve the python practice 0 uploaded to the virtual campus
#
# ## Deadline: 5/10/23

# %%
#Cálculo del límite de la función mediante iteraciones

import numpy as np
import matplotlib.pyplot as plt

#Función que voy a integrar
def funcion(x):
    return -(x * x) + 5

#Escribo la función en la consola
print("f(x)= -x^2 + 5")

#puntos límite de la funcion
lim1 = -2
lim2 = 2

#Genero la funcion con puntos x e y
fun_x = np.linspace(lim1, lim2, 100)
fun_y = funcion(fun_x)

#Cálculo del punto máximo de la funcion
M= np.max(fun_y)
print("Máximo de la función: ",M)

#Para pintar la función y ver de forma gráfica los resultados
def pintaFuncion(fun_x, fun_y, puntos_x, puntos_y):
    # Crea el gráfico
    plt.plot(fun_x, fun_y)
    plt.grid(True)  # Muestra una cuadrícula en el gráfico
    plt.scatter(puntos_x, puntos_y, color='red', s=3)
    
    # Muestra el gráfico
    plt.show()
    
# integral de la función
def integra_mc(fun, a ,b , num_puntos):
    Ndebajo=0
    pos_x = np.random.uniform(a, b, num_puntos)
    pos_y = np.random.uniform(0, M, num_puntos)
    
    puntos_debajo_x = np.array([])
    puntos_debajo_y = np.array([])
    
    for i in range (-5, num_puntos):
        if(pos_y[i] <= fun(pos_x[i])):
            Ndebajo = Ndebajo + 1
            puntos_debajo_x = np.append(puntos_debajo_x, pos_x[i])
            puntos_debajo_y = np.append(puntos_debajo_y, pos_y[i])
            
    pintaFuncion(fun_x, fun_y, puntos_debajo_x, puntos_debajo_y)
    
    return (Ndebajo / num_puntos) * (b-a) * M

#imprimo la solución de la integral
solucion = integra_mc(funcion, lim1, lim2, 10000)
print("Resultado de la integral: ", solucion)
# Out:
# f(x)= -x^2 + 5
# Máximo de la función:  4.999591878379757
# Resultado de la integral:  14.64880420365269

# %% [markdown]
# **Answer in the gape  below**

# %%
#Cálculo del límite de la función mediante operaciones entre vectores
import numpy as np
import matplotlib.pyplot as plt

#Función que voy a integrar
def funcion(x):
    return (x * x) + 5 * x -3

#puntos límite de la funcion
lim1 = 0
lim2 = 10

#Genero la funcion con puntos x e y
fun_x = np.linspace(lim1, lim2, 100)
fun_y = funcion(fun_x)

#Escribo la función en la consola
print("f(x)= x^2 + 5x -3")

#Cálculo del punto máximo de la funcion
M = np.max(fun_y)
print("Máximo de la función: ",M)

#Para pintar la función y ver de forma gráfica los resultados
def pintaFuncion(fun_x,fun_y,puntos_x,puntos_y):
    
    # Crea el gráfico
    plt.plot(fun_x, fun_y)
    plt.grid(True)  # Muestra una cuadrícula en el gráfico
    plt.scatter(puntos_x, puntos_y, color='red', s=3)
    
    # Muestra el gráfico
    plt.show()
    
# integral de la función(mediante operaciones con vectores)
def integra_mc(fun,a,b,num_puntos):
    
    #Genero los puntos aleatorios
    pos_x = np.random.uniform(a, b, num_puntos)
    pos_y = np.random.uniform(0, M, num_puntos)
    
    debajo = pos_y <= fun(pos_x)
    
    puntos_debajo_x = pos_x[debajo]
    puntos_debajo_y = pos_y[debajo]
    
    pintaFuncion(fun_x, fun_y, puntos_debajo_x, puntos_debajo_y)
    
    return np.mean(debajo) * (b - a) * M

#imprimo la solución de la integral
solucion= integra_mc(funcion, lim1, lim2, 10000)
print("Resultado de la integral: ", solucion)
# Out:
# f(x)= x^2 + 5x -3
# Máximo de la función:  147.0
# Resultado de la integral:  547.428

# %%
# Exercise 1

#Busqueda de la plataforma que no tiene first_party
#Dado que hay elementos que corresponden a la misma plataforma pero tienen mayúsculas distintas -> todo a mayúsculas
firstParty['Platform'] = firstParty['Platform'].str.upper()
gameSales['Platform'] = gameSales['Platform'].str.upper()

#Creamos la tabla mergeada
gameSalesMerge = pd.merge(gameSales,firstParty,how='outer',on=('Platform'), indicator=True)

#Filtramos por los que tienen First_Party a NaN
first_parties = gameSalesMerge[gameSalesMerge["First_Party"].isna()]

#Dado que solo nos interesa saber la plataforma, nos quedamos con el primer elemento de cada plataforma
display(first_parties.groupby("Platform").first())


#Consola First_Party que no tiene sales
display(gameSalesMerge[gameSalesMerge['Global_Sales'].isna()])
# Out:
#                Genre        Publisher  NA_Sales  EU_Sales  JP_Sales  \
# Platform
# PC        Simulation  Electronic Arts      0.99      6.42       0.0
#
#           Other_Sales  Global_Sales Rating Critic_Score_Class First_Party  \
# Platform
# PC                0.6          8.01      T          Excelente        None
#
#              _merge
# Platform
# PC        left_only
#      Platform    Genre Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# 5191       PC  Shooter      Sega       0.0      0.14       0.0         0.01
# 7112     VBOY      NaN       NaN       NaN       NaN       NaN          NaN
# 7113      PS5      NaN       NaN       NaN       NaN       NaN          NaN
#
#       Global_Sales Rating Critic_Score_Class First_Party      _merge
# 5191           NaN      M          Excelente         NaN   left_only
# 7112           NaN    NaN                NaN    Nintendo  right_only
# 7113           NaN    NaN                NaN        Sony  right_only

# %%
# Exercise 2

#Limpieza de valores NaN

#Para los numéricos -> media
gameSalesMerge["NA_Sales"].fillna(gameSales["NA_Sales"].mean(),inplace=True)
gameSalesMerge["EU_Sales"].fillna(gameSalesMerge["EU_Sales"].mean(),inplace=True)
gameSalesMerge["Other_Sales"].fillna(gameSalesMerge["Other_Sales"].mean(),inplace=True)
gameSalesMerge["JP_Sales"].fillna(gameSalesMerge["JP_Sales"].mean(),inplace=True)
gameSalesMerge["Global_Sales"].fillna(gameSalesMerge["Global_Sales"].mean(),inplace=True)

#Para los strings -> moda
gameSalesMerge["Publisher"].fillna(gameSalesMerge["Publisher"].mode().iloc[0], inplace=True)
gameSalesMerge["Genre"].fillna(gameSalesMerge["Genre"].mode().iloc[0], inplace=True)
gameSalesMerge["Platform"].fillna(gameSalesMerge["Platform"].mode().iloc[0], inplace=True)
gameSalesMerge["Rating"].fillna(gameSalesMerge["Rating"].mode().iloc[0], inplace=True)
gameSalesMerge["Critic_Score_Class"].fillna(gameSalesMerge["Critic_Score_Class"].mode().iloc[0], inplace=True)
gameSalesMerge["First_Party"].fillna(gameSalesMerge["First_Party"].mode().iloc[0], inplace=True)

display(gameSalesMerge)
# Out:
#      Platform         Genre        Publisher   NA_Sales   EU_Sales  JP_Sales  \
# 0         WII        Sports         Nintendo  41.360001  28.959999  3.770000
# 1         WII        Racing         Nintendo  15.680000  12.800000  3.790000
# 2         WII        Sports         Nintendo  15.610000  10.950000  3.280000
# 3         WII          Misc         Nintendo  13.960000   9.180000  2.930000
# 4         WII      Platform         Nintendo  14.480000   6.950000  4.700000
# ...       ...           ...              ...        ...        ...       ...
# 7109       DC  Role-Playing             Sega   0.000000   0.000000  0.090000
# 7110       DC        Racing             Sega   0.000000   0.000000  0.070000
# 7111       DC       Shooter             Sega   0.000000   0.000000  0.050000
# 7112     VBOY        Action  Electronic Arts   0.388567   0.232565  0.062652
# 7113      PS5        Action  Electronic Arts   0.388567   0.232565  0.062652
#
# ...

# %%
#Exercise 3

#In the work folder there is a csv about video game developers (video-games-developers.csv). 
#Clean the dataframe from missing or erroneous values and work with it the way you want

developers = pd.read_csv('video-games-developers.csv')

#Limpiar NaN
developers = developers.dropna();
display(developers)

#Contar cuantas veces aparece cada 'Administrative division'
display(developers['Administrative division'].value_counts())

#Entradas ordenadas por año
display(developers.sort_values(by='Est.'))

#Todas las entradas de la ciudad más repetida
display(developers[developers['City'] == developers['City'].value_counts().idxmax()])
# Out:
#                   Developer           City Administrative division  \
# 1            11 bit studios         Warsaw    Masovian Voivodeship
# 6                 2K Sports         Novato              California
# 7            343 Industries        Redmond              Washington
# 8                38 Studios     Providence            Rhode Island
# 13              989 Studios    Foster City              California
# ..                      ...            ...                     ...
# 671          Wideload Games        Chicago                Illinois
# 676       Xbox Game Studios        Redmond              Washington
# 680  ZeniMax Online Studios    Hunt Valley                Maryland
# 682      Zipper Interactive        Redmond              Washington
# 685                   Zynga  San Francisco              California
#
#            Country  Est.                Notable games, series or franchises  \
# 1           Poland  2010                                          Frostpunk
# ...
